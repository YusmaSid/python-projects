# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk(r'input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Data=pd.read_csv(r"c:\Users\Yusma\Desktop\Python\workspace\archive\physics_particles.csv")
Data.head()
# Out:
#    pdg_id pdg_name          name  charge  rank quarks          mass  \
# 0   -2212        p   anti_proton    -1.0     4    UUD  938.27208816
# 1   -2112        n  anti_neutron     0.0     4    UDD   939.5654205
# 2    -321        K         kaon-    -1.0     0     Us       493.677
# 3    -211       pi         pion0    -1.0     0     Ud     139.57039
# 4     -24        W            W-    -1.0     0      -       80379.0
#
#   mass_lower mass_upper       width width_lower width_upper
# 0    2.9e-07    2.9e-07         0.0         0.0         0.0
# 1      5e-07      5e-07   7.493e-25       4e-28       4e-28
# 2      0.016      0.016   5.317e-14       9e-17       9e-17
# 3    0.00018    0.00018  2.5284e-14       5e-18       5e-18
# 4       12.0       12.0      2080.0        40.0        40.0

# %%
Data.describe()
# Out:
#             pdg_id     charge       rank
# count    46.000000  46.000000  46.000000
# mean    496.478261  -0.043478   0.956522
# std    1341.075236   0.687126   1.725064
# min   -2212.000000  -1.000000   0.000000
# 25%      -5.750000  -0.666667   0.000000
# 50%       8.500000   0.000000   0.000000
# 75%      89.500000   0.333333   0.000000
# max    3334.000000   1.000000   4.000000

# %%
Data.shape
# Out:
# (46, 12)

# %%
Data.tail(5)
# Out:
#     pdg_id pdg_name    name  charge  rank quarks      mass mass_lower  \
# 41    3212    Sigma  sigma0     0.0     4    uds  1192.642      0.024
# 42    3222    Sigma  sigma+     1.0     4    uus   1189.37       0.07
# 43    3312       Xi     xi-    -1.0     4    dss   1321.71       0.07
# 44    3322       Xi     xi0     0.0     4    uss   1314.86        0.2
# 45    3334    Omega  omega-    -1.0     4    sss   1672.45       0.29
#
#    mass_upper      width width_lower width_upper
# 41      0.024     0.0089      0.0008      0.0009
# 42       0.07  8.209e-12     2.7e-14     2.7e-14
# 43       0.07   4.02e-12       4e-14       4e-14
# 44        0.2   2.27e-12       7e-14       7e-14
# 45       0.29   8.02e-12     1.1e-13     1.1e-13

# %%
Data.boxplot()
# Out:
# <Axes: >

# %%
Data.hist()
# Out:
# array([[<Axes: title={'center': 'pdg_id'}>,
#         <Axes: title={'center': 'charge'}>],
#        [<Axes: title={'center': 'rank'}>, <Axes: >]], dtype=object)

# %%
Data.columns
# Out:
# Index(['pdg_id', 'pdg_name', 'name', 'charge', 'rank', 'quarks', 'mass',
#        'mass_lower', 'mass_upper', 'width', 'width_lower', 'width_upper'],
#       dtype='object')

# %%
Data.info
# Out:
# <bound method DataFrame.info of     pdg_id pdg_name                      name    charge  rank  \
# 0    -2212        p               anti_proton -1.000000     4
# 1    -2112        n              anti_neutron  0.000000     4
# 2     -321        K                     kaon- -1.000000     0
# 3     -211       pi                     pion0 -1.000000     0
# 4      -24        W                        W- -1.000000     0
# 5      -16  nu(tau)         anti_tau_neutrino  0.000000     0
# 6      -15      tau                  anti_tau  1.000000     0
# 7      -14   nu(mu)        anti_muon_neutrino  0.000000     0
# 8      -13       mu                 anti_muon  1.000000     0
# 9      -12    nu(e)    anti_electron_neutrino  0.000000     0
# 10     -11        e  anti_electron (positron)  1.000000     0
# 11      -6        t                  anti_top -0.666667     0
# 12      -5        b               anti_bottom  0.333333     0
# 13      -4        c                anti_charm -0.666667     0
# ...

# %%
Data.isnull()
# Out:
#     pdg_id  pdg_name   name  charge   rank  quarks   mass  mass_lower  \
# 0    False     False  False   False  False   False  False       False
# 1    False     False  False   False  False   False  False       False
# 2    False     False  False   False  False   False  False       False
# 3    False     False  False   False  False   False  False       False
# 4    False     False  False   False  False   False  False       False
# 5    False     False  False   False  False   False  False       False
# 6    False     False  False   False  False   False  False       False
# 7    False     False  False   False  False   False  False       False
# 8    False     False  False   False  False   False  False       False
# 9    False     False  False   False  False   False  False       False
# 10   False     False  False   False  False   False  False       False
# 11   False     False  False   False  False   False  False       False
# ...

# %%
Data.isnull().sum()
# Out:
# pdg_id         0
# pdg_name       0
# name           0
# charge         0
# rank           0
# quarks         0
# mass           0
# mass_lower     0
# mass_upper     0
# width          0
# width_lower    0
# width_upper    0
# dtype: int64

# %%
grp=Data.groupby('pdg_name')
x=grp['pdg_id'].agg(np.mean)
y=grp['charge'].agg(np.mean)
z=grp['rank'].agg(np.mean)
print(x)
print(y)
print(z)
# Out:
# pdg_name
# H            25.0
# K             0.0
# Lambda     3122.0
# Omega      3334.0
# Sigma      3182.0
# W             0.0
# Xi         3317.0
# Z            23.0
# b             0.0
# c             0.0
# d             0.0
# e             0.0
# g            21.0
# gamma        22.0
# mu            0.0
# n             0.0
# nu(e)         0.0
# nu(mu)        0.0
# nu(tau)       0.0
# p             0.0
# pi           37.0
# s             0.0
# t             0.0
# tau           0.0
# u             0.0
# Name: pdg_id, dtype: float64
# pdg_name
# H          0.0
# K          0.0
# Lambda     0.0
# Omega     -1.0
# Sigma      0.0
# W          0.0
# Xi        -0.5
# Z          0.0
# b          0.0
# c          0.0
# d          0.0
# e          0.0
# g          0.0
# gamma      0.0
# mu         0.0
# n          0.0
# nu(e)      0.0
# nu(mu)     0.0
# nu(tau)    0.0
# p          0.0
# pi         0.0
# s          0.0
# t          0.0
# tau        0.0
# u          0.0
# ...

# %%
plt.xticks(rotation=90)
plt.plot(x)

# %%
Data.apply(lambda x: len(x.unique()))
# Out:
# pdg_id         46
# pdg_name       25
# name           46
# charge          7
# rank            2
# quarks         28
# mass           26
# mass_lower     23
# mass_upper     24
# width          19
# width_lower    19
# width_upper    19
# dtype: int64

# %%
# %pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

charge = Data.charge.value_counts()

plt.figure(figsize=(4, 2))
sns.barplot(x=charge.index, y=charge.values, color='b')
plt.xticks(rotation=90)
plt.show()
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 262.6 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.9 kB 281.8 kB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# ...

# %%
charge = Data.charge.value_counts()

print(charge)
# Out:
# charge
#  0.000000    16
# -1.000000    10
#  1.000000     8
# -0.666667     3
#  0.333333     3
# -0.333333     3
#  0.666667     3
# Name: count, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
